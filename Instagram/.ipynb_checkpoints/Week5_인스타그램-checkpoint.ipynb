# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import time
import re
import pandas as pd
from urllib.request import urlopen
from urllib.parse import quote_plus

# %% [markdown]
# ---
# ### 크롤링 - 인스타그램

# %%
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

def instagram_login():

    # 개인정보 보호 오류 창... 
    driver.find_element_by_css_selector('#details-button').click(); time.sleep(1)
    driver.find_element_by_css_selector('#proceed-link').click(); time.sleep(2)
    # 로그인
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('아이디')
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys('비밀번호')
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button/div').click(); time.sleep(5)
    # 로그인 정보 저장 (나중에 하기)
    driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
    time.sleep(3) 
    # 알림설정 (나중에 하기)
    driver.find_element_by_xpath('/html/body/div[4]/div/div/div/div[3]/button[2]').click()
    time.sleep(3)

# 첫게시물 보기
def select_first(driver):
    first = driver.find_element_by_css_selector("div._9AhH0")
    first.click()
    time.sleep(3)

# 다음게시글
def move_next(driver):
    right = driver.find_element_by_css_selector ('a.coreSpriteRightPaginationArrow')
    right.click()
    time.sleep(3)

# 내용 훔쳐오기
def get_content(driver):
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    try:
        content = soup.select('div.C4VMK > span')[0].text
    except:
        content = ' '
        
    # 해시태그 > 정규표현식
    tags = re.findall(r'#[^\s#,\\]+', content) 
    # 작성일자
    date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10]
    # 좋아요 수
    try:
        like = soup.select('a.zV_Nj')[0].text[4:-1]   
    except:
        like = 0
    # 위치정보
    try: 
        place = soup.select('div.M30cS')[0].text
    except:
        place = ''
    # 리스트로 저장
    data = [content, date, like, place, tags]
    return data

# %% [markdown]
# #### 텍스트

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get('https://www.instargram.com')

instagram_login()

# 검색결과
driver.get(insta_searching('별의커비'))
time.sleep(4)

# 함수 차례대로 실행
select_first(driver)
results = [ ]
target = 33    # 가져올 게시글 수
for i in range(target):
    # 수집 오류 > 2초 대기
    try:
        data = get_content(driver)    # 게시글 정보
        results.append(data)
        move_next(driver)
    except:
        time.sleep(2)
        move_next(driver)
    
driver.close()

# %%
df2 = pd.DataFrame(results)
df2.columns = ['content','data','like','place','tags']
df2.to_excel('별의커비 해시태그.xlsx', index=False) 

pd.read_excel('별의커비 해시태그.xlsx')
# Out:
#                                               content        data   like  \
# 0                                ⠀쉬는날엔 택배받는날모코모코 파우치😍  2020-04-13    115
# 1                              Ready to play🎮💖 #Kirby  2020-03-19  2,262
# 28  코로나때문에 거의 반년만에 오빠랑 둘이서 외식🙊지환지호 픽업해서 게임매장가서지환이 ...  2021-02-23     10
# 29                 늦잠 자는 친구를 깨워볼까요? 😴 노래 부르기는 금지!🎶🚫 🤫  2021-02-23    103
# 30      星のカービーにハマっている息子。作品が増えていく〜😂#星のカービー#아이클레이 #별의커비  2021-02-23      1
# 31  #홍대피규어샵 #제일복권 #카메하우스2021.02.23. #카메하우스홍대점 제일복권...  2021-02-23      6
#
#                       place                                               tags
# 0                       NaN                                                 []
# 1                       NaN                                         ['#Kirby']
# 2                       NaN  ['#カービィ', '#星のカービィ', '#星之卡比', '#커비', '#별...
# 3                       NaN                                                 []
# 4                       NaN                                         ['#Kirby']
# 5                       NaN                              ['#fanart', '#Kirby']
# 6                       NaN                                         ['#Kirby']
# 7                       NaN  ['#Kirby', '#swordkirby', '#cleaningkirby', '#...
# 8                       NaN           ['#AnimalCrossing', '#fanart', '#Kirby']
# 9                       NaN  ['#8살아들', '#생일', '#생일선물', '#입학선물', '#닌텐도스위치라이트...
# 10                      NaN  ['#닌텐도', '#육아일상', '#별의커비드뎌'...
# 11                      애니통  ['#세일러문', '#귀멸의칼날', '#별의커비', '#카드캡터사쿠라', '#가면라...
# 12                      NaN            ['#kirby', '#星のカービィ', '#星之卡比', '#별의커비']
# 13          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#대전굿즈샵', '#귀칼', '#귀멸', '...
# 14          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#리멘트', '#대전굿즈샵',...
# 15          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#대전굿즈샵', '#귀멸', '#귀칼', '...
# 16          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#주술회전👉🏻', '#대전굿즈샵', '#주술...
# 17          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#주술회전👉🏻', '#대전ᄀ...
# 18          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#대전굿즈샵', '#귀멸', '#귀칼', '...
# 19          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#약속의네버랜드👉🏻', '#약네랜', '#엠...
# 20          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#명탐정코난👉🏻', '#대전굿즈샵', '#명...
# 21          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#앙스타', '#대전굿즈샵', '#대전제이굿...
# 22          은행동 으능정이 문화의 거리  ['#대전제이굿즈🌟', '#한정상품👉🏻', '#대전굿즈샵', '#진격...
# 23                      NaN                 ['#별의커비', '#커비가챠', '#웨이들디', '#커비']
# 24                      NaN  ['#kirbystarallies', '#カービィ', '#星のカービィ', '#カービ...
# 25                      NaN  ['#공스타그램', '#좋반', '#좋아요반사', '#공부인증', '#공스타맞팔',...
# 26                      NaN                   ['#별의커비같이', '#부자스타그램', '#아빠와아들']
# 27                      NaN                                                 []
# 28  Osan, Kyonggi-Do, Korea  ['#코로나저리꺼져', '#세뱃돈탈탈', '#닌텐도스위치', '#링피트다이어트', ...
# 29                      NaN                                                 []
# 30                      NaN                     ['#星のカービー', '#아이클레이', '#별의커비']
# 31                    카메하우스  ['#홍대피규어샵', '#제일복권', '#카메하우스2021.02.23.', '#카메...

# %% [markdown]
# #### 이미지

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get('https://www.instargram.com')

instagram_login()

driver.get(insta_searching('별의커비'))
time.sleep(4)

html = driver.page_source
soup = BeautifulSoup(html)

insta = soup.select('.v1Nh3.kIKUG._bz0w')

n = 1
for i in insta:
    print('https://www.instagram.com'+ i.a['href'])
    imgUrl = i.select_one('.KL4Bh').img['src']
    with urlopen(imgUrl) as f:
        with open('./img/' + '별의커비' + str(n) + '.jpg', 'wb') as h:
            img = f.read()
            h.write(img)
    n += 1
    print(imgUrl)
    print()

driver.close()
# Out:
# https://www.instagram.com/p/B-546lYFEyr/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/93402320_732805950456744_4226925869123551691_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=BpkwlywD0wMAX_GBCRG&tp=1&oh=200497aadbd2f6a964f2d6b3e213452b&oe=60607697
#
# https://www.instagram.com/p/B96sx5YpOQB/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/82993872_1107027166328524_2975569197304642512_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=104&_nc_ohc=b81FuxPnUlAAX-NFNxZ&tp=1&oh=7eb853e2eaa560e2bbd6b4c90d4d589d&oe=6060B4EF
#
# https://www.instagram.com/p/CJ3ZS6dJl3i/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c187.0.706.706a/s640x640/136969411_223247452667856_7986089384224024910_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=BSdjCk5onH8AX9KlEae&tp=1&oh=8aa1993aad74e682820c02acd3836714&oe=605F9682
#
# https://www.instagram.com/p/B3MQWLSFtD9/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/71506634_2728219820737969_5654401569993736687_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=Q_S5vzH-_nYAX__A4rx&tp=1&oh=dac2164c6ca5ce71a39ebbdee481bd51&oe=605F4A4A
#
# https://www.instagram.com/p/CDBc7o5pQVJ/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c67.0.1306.1306a/s640x640/116066757_308133553878574_6562087912709501834_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=dSH4KSMPEhYAX_9YxkK&tp=1&oh=48063c4c09a3033c2e73d0dc889fcd61&oe=60629DCD
#
# https://www.instagram.com/p/CCyV347pcTx/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c87.0.1266.1266a/s640x640/108633940_3420382867994733_6929830408303185642_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=109&_nc_ohc=cC3PdWbPNM0AX9A_gkc&tp=1&oh=ee18deb2b6deadc4cb0f7d3edda3112e&oe=605FC848
#
# https://www.instagram.com/p/CDDWTSApZeQ/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c137.0.1166.1166a/s640x640/111173009_290284625518362_8253021735192507771_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=106&_nc_ohc=IPclHYFELfEAX9nBfh_&tp=1&oh=d395bba5cf889d640018ac9a65659d02&oe=60627CE3
#
# https://www.instagram.com/p/B7uvszYJmWV/
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/82509932_558540384875392_2595252785961584178_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=104&_nc_ohc